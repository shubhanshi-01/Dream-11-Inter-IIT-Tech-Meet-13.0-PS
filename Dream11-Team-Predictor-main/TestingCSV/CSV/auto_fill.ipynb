# %%
path = "Aus_England_27_Sep.csv"

import pandas as pd

# %%
data = pd.read_csv(path)
data
# Out:
#        Player Name      Squad  Match Date Format
# 0          PD Salt    England  2024-09-27    ODI
# 1       BM Duckett    England  2024-09-27    ODI
# 2         WG Jacks    England  2024-09-27    ODI
# 3         HC Brook    England  2024-09-27    ODI
# 4         JL Smith    England  2024-09-27    ODI
# 5   LS Livingstone    England  2024-09-27    ODI
# 6       JG Bethell    England  2024-09-27    ODI
# 7         BA Carse    England  2024-09-27    ODI
# 8        AU Rashid    England  2024-09-27    ODI
# 9         MJ Potts    England  2024-09-27    ODI
# 10       JC Archer    England  2024-09-27    ODI
# 11        MR Marsh  Australia  2024-09-27    ODI
# 12         TM Head  Australia  2024-09-27    ODI
# 13       SPD Smith  Australia  2024-09-27    ODI
# 14       JP Inglis  Australia  2024-09-27    ODI
# 15   M Labuschagne  Australia  2024-09-27    ODI
# 16        AT Carey  Australia  2024-09-27    ODI
# 17      GJ Maxwell  Australia  2024-09-27    ODI
# ...
